# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tqdm import tqdm_notebook as tqdm
# %matplotlib inline
#%load_ext line_profiler

# %%
train_df = pd.read_csv('../../data/train.csv')
structure_df = pd.read_csv('../../data/structures.csv')

# %%
train_df.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant
# 0                   84.8076
# 1                  -11.2570
# 2                  -11.2548
# 3                  -11.2543
# 4                   84.8074

# %%
structure_df.head(150)
# Out:
#         molecule_name  atom_index atom         x         y         z
# 0    dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1    dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2    dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3    dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4    dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
# 5    dsgdb9nsd_000002           0    N -0.040426  1.024108  0.062564
# 6    dsgdb9nsd_000002           1    H  0.017257  0.012545 -0.027377
# 7    dsgdb9nsd_000002           2    H  0.915789  1.358745 -0.028758
# 8    dsgdb9nsd_000002           3    H -0.520278  1.343532 -0.775543
# 9    dsgdb9nsd_000003           0    O -0.034360  0.977540  0.007602
# 10   dsgdb9nsd_000003           1    H  0.064766  0.020572  0.001535
# 11   dsgdb9nsd_000003           2    H  0.871790  1.300792  0.000693
# 12   dsgdb9nsd_000004           0    C  0.599539  0.000000  1.000000
# ...

# %%
structure_df[structure_df['atom']=="C"]
# Out:
#             molecule_name  atom_index atom         x         y         z
# 0        dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 12       dsgdb9nsd_000004           0    C  0.599539  0.000000  1.000000
# 13       dsgdb9nsd_000004           1    C -0.599539  0.000000  1.000000
# 16       dsgdb9nsd_000005           0    C -0.013324  1.132466  0.008276
# 19       dsgdb9nsd_000007           0    C -0.018704  1.525582  0.010433
# 20       dsgdb9nsd_000007           1    C  0.002104 -0.003882  0.001999
# 27       dsgdb9nsd_000008           0    C -0.008288  1.390470 -0.005601
# 33       dsgdb9nsd_000009           0    C -0.017821  1.464358  0.010094
# 34       dsgdb9nsd_000009           1    C  0.002088  0.009508  0.002012
# 35       dsgdb9nsd_000009           2    C  0.018341 -1.191805 -0.004505
# 40       dsgdb9nsd_000010           0    C -0.017886  1.467128  0.010113
# 41       dsgdb9nsd_000010           1    C  0.001738  0.010353  0.002076
# ...

# %%
count = 1
before = None
for _, i in tqdm(structure_df[structure_df['atom']=="C"].iterrows(),total= len(structure_df[structure_df['atom']=="C"])):

    if i[0] == before:
        count+=1
    else: 
        before = i[0]
        count = 1
    if count >= 6:
        print(before)
# Out:
# ...
# dsgdb9nsd_000214
# dsgdb9nsd_000219
# dsgdb9nsd_000228
# dsgdb9nsd_000233
# dsgdb9nsd_000250
# dsgdb9nsd_000274
# dsgdb9nsd_000291
# dsgdb9nsd_000294
# dsgdb9nsd_000301
# dsgdb9nsd_000311
# dsgdb9nsd_000316
# dsgdb9nsd_000327
# dsgdb9nsd_000371
# dsgdb9nsd_000391
# dsgdb9nsd_000398
# dsgdb9nsd_000414
# dsgdb9nsd_000432
# dsgdb9nsd_000456
# dsgdb9nsd_000459
# dsgdb9nsd_000462
# dsgdb9nsd_000466
# dsgdb9nsd_000473
# dsgdb9nsd_000478
# dsgdb9nsd_000484
# dsgdb9nsd_000487
# dsgdb9nsd_000505
# dsgdb9nsd_000506
# dsgdb9nsd_000511
# dsgdb9nsd_000517
# dsgdb9nsd_000522
# dsgdb9nsd_000525
# dsgdb9nsd_000543
# dsgdb9nsd_000551
# dsgdb9nsd_000563
# dsgdb9nsd_000571
# dsgdb9nsd_000585
# dsgdb9nsd_000588
# dsgdb9nsd_000598
# dsgdb9nsd_000617
# dsgdb9nsd_000634
# dsgdb9nsd_000640
# dsgdb9nsd_000646
# dsgdb9nsd_000648
# dsgdb9nsd_000651
# dsgdb9nsd_000656
# dsgdb9nsd_000658
# dsgdb9nsd_000662
# dsgdb9nsd_000665
# dsgdb9nsd_000669
# dsgdb9nsd_000673
# dsgdb9nsd_000688
# dsgdb9nsd_000695
# ...

# %%
train_df[train_df["molecule_name"] == 'dsgdb9nsd_002375']
# Out:
#           id     molecule_name  atom_index_0  atom_index_1  type  \
# 59960  59960  dsgdb9nsd_002375             7             0  1JHC
# 59961  59961  dsgdb9nsd_002375             7             1  2JHC
# 59962  59962  dsgdb9nsd_002375             7             2  3JHC
# 59963  59963  dsgdb9nsd_002375             7             3  3JHC
# 59964  59964  dsgdb9nsd_002375             7             8  2JHH
# 59965  59965  dsgdb9nsd_002375             7             9  2JHH
# 59966  59966  dsgdb9nsd_002375             7            10  3JHH
# 59967  59967  dsgdb9nsd_002375             8             0  1JHC
# 59968  59968  dsgdb9nsd_002375             8             1  2JHC
# 59969  59969  dsgdb9nsd_002375             8             2  3JHC
# 59970  59970  dsgdb9nsd_002375             8             3  3JHC
# 59971  59971  dsgdb9nsd_002375             8             9  2JHH
# 59972  59972  dsgdb9nsd_002375             8            10  3JHH
# ...

# %%
structure_df[structure_df["molecule_name"] == 'dsgdb9nsd_002375']
# Out:
#           molecule_name  atom_index atom         x         y         z
# 32775  dsgdb9nsd_002375           0    C -0.199177  1.553171  0.014870
# 32776  dsgdb9nsd_002375           1    C -0.025573  0.052248  0.064419
# 32777  dsgdb9nsd_002375           2    C  1.274540 -0.603590 -0.254018
# 32778  dsgdb9nsd_002375           3    C  0.769040 -0.653259  1.178531
# 32779  dsgdb9nsd_002375           4    C  1.484567  0.140577  2.218577
# 32780  dsgdb9nsd_002375           5    C  1.301333 -0.328963  3.651137
# 32781  dsgdb9nsd_002375           6    O  2.172812  1.105464  1.949593
# 32782  dsgdb9nsd_002375           7    H  0.699952  2.066024  0.359700
# 32783  dsgdb9nsd_002375           8    H -0.408009  1.871841 -1.012314
# 32784  dsgdb9nsd_002375           9    H -1.039280  1.875350  0.639829
# 32785  dsgdb9nsd_002375          10    H -0.911556 -0.508170 -0.224293
# 32786  dsgdb9nsd_002375          11    H  1.284328 -1.531474 -0.814792
# ...

# %%
a = np.array([-0.199177, 1.553171,0.014870])
b = np.array([-0.025573,0.05224,0.064419])
c = np.array([1.274540,-0.603590,-0.254018])
d = np.array([0.769040,0.653259,1.178531])
e = np.array([-0.408009,1.871841,-1.012314])

# %%
np.linalg.norm(a - e,ord = 2)
# Out:
# 1.0955675894165544

# %%
np.linalg.norm(b - e,ord = 2)
# Out:
# 2.148617938719213

# %%
np.linalg.norm(c - e,ord = 2)
# Out:
# 3.087675921591837

# %%
np.linalg.norm(d - e,ord = 2)
# Out:
# 2.769510471753086
